# %% [markdown]
# # Global Sales Predictions

# %% [markdown]
# Importing Modules

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# Reading Data Set

# %%
df=pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')

# %% [markdown]
# Dropping Unnecessary Columns

# %%
df.drop(columns = ['Year_of_Release', 'Developer', 'Publisher', 'Platform'], inplace = True)

# %%
x=df.iloc[:,:].values
y=df.iloc[:,6:7]
x=np.delete(x,6,1)

# %% [markdown]
# Spliting The DataSet for Training

# %%
from sklearn.model_selection import train_test_split as tts
x_train,x_test,Y_train,Y_test=tts(x,y,test_size=0.3)
games_in_training_set = x_train[:, 0]
games_in_test_set = x_test[:, 0]

# %% [markdown]
# Dropping Name Column

# %%
x_train=x_train[:,1:]
x_test=x_test[:,1:]

# %% [markdown]
# Imputing The Test and training Case

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer()
x_train[:, [5 ,6, 7, 8]] = imputer.fit_transform(x_train[:, [5, 6, 7, 8]])
x_test[:, [5 ,6, 7, 8]] = imputer.fit_transform(x_test[:, [5, 6, 7, 8]])

# %% [markdown]
# Using Categorical imputer to Fill nan Values with 'NA'

# %%
from sklearn_pandas import CategoricalImputer
categorical_imputer = CategoricalImputer(strategy = 'constant', fill_value = 'NA')
x_train[:, [0, 9]] = categorical_imputer.fit_transform(x_train[:, [0, 9]])
x_test[:, [0, 9]] = categorical_imputer.transform(x_test[:, [0, 9]])

# %% [markdown]
# Using Column Transformer Transfrom every Column

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers = [('encoder', OneHotEncoder(), [0, 9])], remainder = 'passthrough') 
x_train = ct.fit_transform(x_train)
x_test = ct.transform(x_test)

# %% [markdown]
# Creating and Training The Model

# %%
from xgboost import XGBRegressor
model = XGBRegressor(n_estimators = 200, learning_rate= 0.08)
model.fit(x_train, Y_train)
# Out:
# [11:39:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.08, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=200,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %% [markdown]
# # Predicting The Sales and Putting them in a seperate Dataset

# %%
Y_pred = model.predict(x_test)
games_in_test_set = games_in_test_set.reshape(-1,1)
Y_pred = Y_pred.reshape(-1, 1)
predictions = np.concatenate([games_in_test_set, Y_pred, Y_test], axis = 1)
predictions = pd.DataFrame(predictions, columns = ['Name', 'Predicted_Global_Sales', 'Actual_Global_Sales'])

# %%
predictions.head(10)
# Out:
#                                                 Name  ... Actual_Global_Sales
# 0                 Majesty 2: The Fantasy Kingdom Sim  ...                0.02
# 1                        Pro Yakyuu Team o Tsukurou!  ...                0.23
# 2  Naruto Shippuden: Ultimate Ninja Storm Revolution  ...                0.43
# 3                                   Wheel of Fortune  ...                0.25
# 4                Ar tonelico 2: Melody of Metafalica  ...                0.18
# 5                                 Samurai Warriors 4  ...                0.24
# 6                             Secret Files: Tunguska  ...                0.06
# 7                                        Million God  ...                0.09
# 8                                      Rocket League  ...                0.06
# 9                                          Max Payne  ...                1.22
#
# [10 rows x 3 columns]

# %% [markdown]
# Calculating r2 Score

# %%
from sklearn.metrics import r2_score, mean_squared_error
import math
r2_score = r2_score(Y_test, Y_pred)
rmse = math.sqrt(mean_squared_error(Y_test, Y_pred))
print(f"r2 score of the model : {r2_score:.3f}")
print(f"Root Mean Squared Error of the model : {rmse:.3f}")
# Out:
# r2 score of the model : 0.861
# Root Mean Squared Error of the model : 0.648

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(Y_test,Y_pred))
# Out:
# 0.035204369492793194

# %% [markdown]
# Scatter Plot of Prediction and Test Data

# %%
px.scatter(predictions,title='Scatter Plot of Predicted_values and Actual Values',x='Actual_Global_Sales',y='Predicted_Global_Sales',hover_data=['Name'],log_x=True,size_max=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8ea3be74-6b13-4271-a3d5-8f875ae367de" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8ea3be74-6b13-4271-a3d5-8f875ae367de")) {
#                     Plotly.newPlot(
#                         '8ea3be74-6b13-4271-a3d5-8f875ae367de',
#                         [{"customdata": [["Majesty 2: The Fantasy Kingdom Sim"], ["Pro Yakyuu Team o Tsukurou!"], ["Naruto Shippuden: Ultimate Ninja Storm Revolution"], ["Wheel of Fortune"], ["Ar tonelico 2: Melody of Metafalica"], ["Samurai Warriors 4"], ["Secret Files: Tunguska"], ["Million God"], ["Rocket League"], ["Max Payne"], ["Hitotsu Tobashi Renai V"], ["Worms"], ["Minna no DS Seminar: Kanpeki Eitango Ryoku"], ["Zenkoku Dekotora Matsuri"], ["Mike Piazza's Strike Zone"], ["Marvel vs. Capcom 3: Fate of Two Worlds"], ["Hot 'n' Cold"], ["Koihime Enbu"], ["Wordmaster"], ["Dark Sector"], ["Darksiders II"], ["The Incredibles: Rise of the Underminer"], ["Sakura Wars: Atsuki Chishio Ni"], ["Commandos: Strike Force"], ["We Sing Pop!"], ["Cities: Skylines"], ["Zen-Nippon Pro Wrestling: Ouja no Kon"], ["Brain Voyage"], ["Capcom Fighting Evolution"], ["Grand Theft Auto V"], ["NCAA Football 10"], ["Road & Track Presents: The Need for Speed"], ["Patapon"], ["Sniper: Ghost Warrior 2"], ["Style Lab: Jewelry Design"], ["Terraria"], ["Monster Jam: Maximum Destruction"], ["The Witcher"], ["Def Jam Vendetta"], ["The Lord of the Rings: War in the North"], ["Atari Anniversary Advance"], ["Chrono Trigger"], ["Yakuza 2"], ["Dragon Quest Monsters 2"], ["Gears of War: Ultimate Edition"], ["The Settlers 7: Paths to a Kingdom"], ["The Polar Express"], ["Naruto Shippuden: Legends: Akatsuki Rising"], ["Scarface: The World is Yours"], ["Sesame Street: Elmo's Number Journey"], ["Farming Simulator 2015"], ["Pro Evolution Soccer 2012"], ["Namco Museum DS"], ["WWE '13"], ["Cel Damage"], ["Sniper Elite V2"], ["The Legend of Heroes: Trails in the Sky First Chapter"], ["Mike Ty